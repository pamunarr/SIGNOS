# %%
import cv2
import matplotlib.pyplot as plt

# %%
alphabet = [
    'A', 'B', 'C', 'CH', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'LL', 'M',
    'N', 'N_', 'O', 'P', 'Q', 'R', 'RR', 'S', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z'
]
for letter in ['M']:
    video_path = "../Datos/Brutos/Letras_Spread/%s.mp4" % letter
    image_path = "../Datos/Brutos/Letras_Spread/%s.jpg" % letter

# %%
vid_cap.release()
vid_cap = cv2.VideoCapture(video_path)

# %%
uuiu = plt.imread(image_path)
plt.imshow(uuiu)

# %%
i = -1

# %%
ret, frame = vid_cap.read()
i += 1
if ret:
    print(i)
    plt.imshow(frame[:, :, [2,1,0]])
    plt.show()
# Out:
# 34

# %%
frame.shape
# Out:
# (240, 320, 3)

# %%
uuiu.shape
# Out:
# (365, 500, 3)

# %%
plt.imshow(frame[:, :, [2,1,0]])

# %%
plt.imshow(uuiu)
